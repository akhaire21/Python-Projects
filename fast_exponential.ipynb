# %%
TOLERANCE = 1e-6
def close_enough(x,y):
    return abs(x - y) < TOLERANCE
def run_test(function, expected, args):
    print(f"args = {args}")
    if(len(args) == 1):
        print("made it into the if statement")
        args = args[0]
        print(f"args = {args}")
        if function(args) == expected:
            print(f"PASS for case {args}")
        else:
            print(f"FAIL because f({args}) != {expected}")
    else:
        if function(*args) == expected:
            print(f"PASS for case {args}")
        else:
            print(f"FAIL because f({args}) != {expected}")
def run_test_float(function, expected, args):
    if(type(args) == list and len(args) == 1):
        args = args[0]
        if close_enough(function(args), expected):
            print(f"PASS for case {args}")
        else:
            print(f"FAIL because f({args}) != {expected}")
        return
    else:
        if close_enough(function(*args), expected):
            print(f"PASS for case {args}")
        else:
            print(f"FAIL because f({args}) != {expected}")

# %%
def pow(base,exp):
  if exp == 0:
    return 1
  tmp = 1
  while exp > 1:
    if (exp % 2) == 0:
      base = base * base
      exp = exp / 2
    else:
      exp = (exp - 1)/2
      tmp = tmp * base
      base = base * base
  return base * tmp

# %%
x=25
y=0
while y<50:
  print(x,y,pow(x,y))
  y+=1
# Out:
# 25 0 1
# 25 1 25
# 25 2 625
# 25 3 15625
# 25 4 390625
# 25 5 9765625
# 25 6 244140625
# 25 7 6103515625
# 25 8 152587890625
# 25 9 3814697265625
# 25 10 95367431640625
# 25 11 2384185791015625
# 25 12 59604644775390625
# 25 13 1490116119384765625
# 25 14 37252902984619140625
# 25 15 931322574615478515625
# 25 16 23283064365386962890625
# 25 17 582076609134674072265625
# 25 18 14551915228366851806640625
# 25 19 363797880709171295166015625
# 25 20 9094947017729282379150390625
# 25 21 227373675443232059478759765625
# 25 22 5684341886080801486968994140625
# 25 23 142108547152020037174224853515625
# 25 24 3552713678800500929355621337890625
# 25 25 88817841970012523233890533447265625
# 25 26 2220446049250313080847263336181640625
# 25 27 55511151231257827021181583404541015625
# 25 28 1387778780781445675529539585113525390625
# 25 29 34694469519536141888238489627838134765625
# 25 30 867361737988403547205962240695953369140625
# 25 31 21684043449710088680149056017398834228515625
# 25 32 542101086242752217003726400434970855712890625
# 25 33 13552527156068805425093160010874271392822265625
# 25 34 338813178901720135627329000271856784820556640625
# 25 35 8470329472543003390683225006796419620513916015625
# 25 36 211758236813575084767080625169910490512847900390625
# 25 37 5293955920339377119177015629247762262821197509765625
# 25 38 132348898008484427979425390731194056570529937744140625
# 25 39 3308722450212110699485634768279851414263248443603515625
# 25 40 82718061255302767487140869206996285356581211090087890625
# 25 41 2067951531382569187178521730174907133914530277252197265625
# 25 42 51698788284564229679463043254372678347863256931304931640625
# 25 43 1292469707114105741986576081359316958696581423282623291015625
# 25 44 32311742677852643549664402033982923967414535582065582275390625
# 25 45 807793566946316088741610050849573099185363389551639556884765625
# 25 46 20194839173657902218540251271239327479634084738790988922119140625
# 25 47 504870979341447555463506281780983186990852118469774723052978515625
# 25 48 12621774483536188886587657044524579674771302961744368076324462890625
# 25 49 315544362088404722164691426113114491869282574043609201908111572265625
